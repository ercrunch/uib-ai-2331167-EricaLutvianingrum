# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("./data-smartphone.csv")

# %%
data.sample(10)
# Out:
#         Brand                 Model Storage   RAM  Screen Size (inches)  \
# 314  Motorola  Moto G Stylus (2021)      128     4                  6.4
# 66       Oppo               F19 Pro   128 GB  8 GB                 6.43
# 364    Xiaomi               Poco M3      128     4                 6.53
# 51      Apple     iPhone 11 Pro Max   256 GB  4 GB                  6.5
# 367   Samsung   Galaxy S20 Ultra 5G      512    16                  6.9
# 186    Xiaomi     Redmi Note 10 Pro    128GB   6GB                 6.67
# 144   Samsung           Galaxy A03s     32GB   3GB                  6.5
# 380    Xiaomi              Redmi 9C       64     3                 6.53
# 198  Motorola    Moto G9 Power Lite     64GB   4GB                  6.5
# 295   Samsung            Galaxy A71      128     6                  6.7
#
#                 Camera (MP)  Battery Capacity (mAh) Price ($)
# 314                  48+8+2                    4000       299
# 66           48 + 8 + 2 + 2                    4310       359
# 364                  48+2+2                    6000       179
# 51             12 + 12 + 12                    3969      1099
# 367            108+48+12+3D                    5000      1399
# 186  64MP + 8MP + 5MP + 2MP                    5020     $329
# 144        13MP + 2MP + 2MP                    5000     $149
# 380                  13+2+2                    5000       119
# 198        48MP + 2MP + 2MP                    6000     $149
# 295               64+12+5+5                    4500       599

# %%
dimensi = data.shape
print("Jumlah baris dan kolom: ", dimensi)

print("Jumlah baris:", dimensi[0])
print("Jumlah baris:", dimensi[1])
# Out:
# Jumlah baris dan kolom:  (407, 8)
# Jumlah baris: 407
# Jumlah baris: 8

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 407 entries, 0 to 406
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Brand                   407 non-null    object
#  1   Model                   407 non-null    object
#  2   Storage                 407 non-null    object
#  3   RAM                     407 non-null    object
#  4   Screen Size (inches)    407 non-null    object
#  5   Camera (MP)             407 non-null    object
#  6   Battery Capacity (mAh)  407 non-null    int64
#  7   Price ($)               407 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 25.6+ KB

# %%
data.isnull().sum()
# untuk memeriksa apakah ada data yang kosong pada setiap kolom
# Out:
# Brand                     0
# Model                     0
# Storage                   0
# RAM                       0
# Screen Size (inches)      0
# Camera (MP)               0
# Battery Capacity (mAh)    0
# Price ($)                 0
# dtype: int64

# %%
data[data.duplicated()]
# untuk memeriksa apakah ada baris yang duplikat dari baris sebelumnya
# Out:
#         Brand                  Model Storage   RAM  Screen Size (inches)  \
# 45      Apple         iPhone 12 Mini    64 GB  4 GB                  5.4
# 61     Xiaomi         Poco M3 Pro 5G    64 GB  4 GB                  6.5
# 132     Nokia                   XR20    128GB   6GB                 6.67
# 170  Motorola       Moto G Stylus 5G    128GB   5GB                  6.8
# 195      Oppo                 A74 5G    128GB   6GB                  6.5
# 221      Vivo                   Y12s     32GB   3GB                 6.51
# 229    Xiaomi  Redmi Note 10 Pro Max    128GB   8GB                 6.67
# 240     Nokia               C20 Plus     32GB   3GB                  6.5
# 246    Xiaomi            Poco X3 Pro    128GB   6GB                 6.67
# 248      Oppo                    A16     32GB   3GB                 6.52
# 260      Vivo                   Y12s     32GB   3GB                 6.51
# 282   Samsung             Galaxy A12     64GB   4GB                  6.5
# 331    Xiaomi            Poco X3 Pro      128     6                 6.67
# 332    Google                Pixel 5      128     8                    6
# 333     Apple       iPhone SE (2020)       64     3                  4.7
# 353     Nokia                 8.3 5G      128     8                 6.81
# 356   Samsung             Galaxy A12      128     4                  6.5
# 357      Oppo                 A94 5G      128     8                 6.43
# 365     Nokia                    5.4       64     4                 6.39
# 377   Samsung       Galaxy S20 FE 5G      128     6                  6.5
# 381   Samsung          Galaxy A32 5G      128     4                  6.5
# 382   OnePlus            Nord N10 5G      128     6                 6.49
# 389    Xiaomi               Redmi 9T      128     4                 6.53
# 390    Google                Pixel 5      128     8                    6
# 398   Samsung          Galaxy A52 5G      128     6                  6.5
# 406   Samsung        Galaxy S10 Lite      128     6                  6.7
#
#                  Camera (MP)  Battery Capacity (mAh) Price ($)
# 45                   12 + 12                    2227       699
# 61                48 + 2 + 2                    5000       199
# 132              48MP + 13MP                    4630     $549
# 170         48MP + 8MP + 5MP                    5000     $399
# 195         48MP + 2MP + 2MP                    5000     $299
# 221               13MP + 2MP                    5000     $149
# 229  108MP + 8MP + 5MP + 2MP                    5020     $329
# 240                8MP + 2MP                    4950      $99
# 246   48MP + 8MP + 2MP + 2MP                    5160     $249
# 248         13MP + 2MP + 2MP                    5000     $149
# 260               13MP + 2MP                    5000     $149
# 282   48MP + 5MP + 2MP + 2MP                    5000     $179
# 331                 48+8+2+2                    5160       249
# 332                  12.2+16                    4080       699
# 333                       12                    1821       399
# 353                64+12+2+2                    4500       499
# 356                 48+5+2+2                    5000       179
# 357                 48+8+2+2                    4310       399
# 365                 48+5+2+2                    4000       179
# 377                  12+12+8                    4500       699
# 381                 48+8+5+2                    5000       279
# 382                 64+8+2+2                    4300       299
# 389                 48+8+2+2                    6000       199
# 390                  12.2+16                    4080       699
# 398                64+12+5+5                    4500       449
# 406                  48+12+5                    4500       649

# %%
data.drop_duplicates(inplace=True)

# drop duplicates
# inplace=True

# %%
data.shape
# Out:
# (381, 8)

# %%
data.columns
# Out:
# Index(['Brand', 'Model', 'Storage ', 'RAM ', 'Screen Size (inches)',
#        'Camera (MP)', 'Battery Capacity (mAh)', 'Price ($)'],
#       dtype='object')

# %% [markdown]
# ### 2. Cleaning the Data

# %%
data["Price ($)"]=data["Price ($)"].str.replace("$","")
data["Price ($)"]=data["Price ($)"].str.replace(",","")
data["Price ($)"]=data["Price ($)"].str.replace(" ","")
data["Price ($)"]=data["Price ($)"].astype("int64")

# %%
data['Storage ']=data['Storage '].str.replace("GB","")
data['Storage ']=data['Storage '].str.replace(" ","")
data['Storage ']=data['Storage '].astype("int64")

# %%
data['RAM ']=data['RAM '].str.replace("GB","")
data['RAM ']=data['RAM '].str.replace(" ","")
data['RAM ']=data['RAM '].astype("int64")

# %%
data['Screen Size (inches)']=data['Screen Size (inches)'].str.replace(" (unfolded)","")
data['Screen Size (inches)']=data['Screen Size (inches)'].apply(lambda x : float(x.split('+')[0].strip()))

# %%
data['Camera (MP)']=data['Camera (MP)'].str.replace("MP","")
data['Camera (MP)']=data['Camera (MP)'].str.replace("3D","")
data['Camera (MP)']=data['Camera (MP)'].str.replace(" ","")

# %%
data['Camera (MP)']=data['Camera (MP)'].str.replace("*","")
data['Camera (MP)']=data['Camera (MP)'].str.replace('[a-zA-Z]',"", regex=True)

# %%
data['Camera (MP)'].unique()
# Out:
# array(['12+12+12', '108+10+10+12', '48+50+8+2', '64+8+5+2', '50+12.2',
#        '12+12', '48+8+2+2', '50+13+16+2', '50+48+12+8', '64+8+2',
#        '64+12+5+5', '50+50+13+3', '64+8+5', '64+12+12', '50+2+2',
#        '48+2+2', '50+8+2+2', '48+5', '48+50+2', '108+8+5+2', '13+2+2',
#        '13+2', '12', '48+5+2', '50+8+2', '64+8+2+2', '48+8+5', '64+8',
#        '48+5+2+2', '50+2', '64+12+8+5', '64+2', '48+13+13', '50+12',
#        '50+16+13+2', '108+16+8', '48+13', '64+13+12', '64+12+8', '13+5',
#        '108+8+2', '64+5+2+2', '64+12', '48+50+8', '50+48+48', '8+2',
#        '12+12+8', '64+13+5', '12+13', '64+8+5+5', '48+8+2', '48+2',
#        '108+12+10+10', '50+5', '48+8+5+5', '108+8+2+2', '13', '48+8+5+2',
#        '13+5+2', '8', '13+5+2+2', '13+8+5+2', '13+8+2+2', '12+2+2',
#        '13+8+2', '25+8+5', '108+12+12', '12.2+16', '50+20+12+',
#        '64+12+2+2', '108+13+5', '48+16+5+2', '12+7', '50+12+40+',
#        '50+8+16+2', '48+12+5', '48+48+8+5', '40+40+8+', '48+12+13',
#        '40+20+8+', '48+16+8', '16+8+5', '16+8+8+2', '12+64+12',
#        '50+40+12+', '108+48+12+', '64+2+2', '48+13+12+2', '108+48+12+0.3',
#        '48+16+2', '48+13+8+2'], dtype=object)

# %%
def clean(x):
    x=x.split('+')
    for i in range(len(x)):
        if(x[-1] == ''):
            x[-1] = 0
        x[i] = float (x[-1])
    return max(x)

data['Camera (MP)']=data['Camera (MP)'].apply(clean)

# %%
data['Camera (MP)']=data['Camera (MP)'].astype("float")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 381 entries, 0 to 405
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Brand                   381 non-null    object
#  1   Model                   381 non-null    object
#  2   Storage                 381 non-null    int64
#  3   RAM                     381 non-null    int64
#  4   Screen Size (inches)    381 non-null    float64
#  5   Camera (MP)             381 non-null    float64
#  6   Battery Capacity (mAh)  381 non-null    int64
#  7   Price ($)               381 non-null    int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 26.8+ KB

# %% [markdown]
# ### 3. Visualize Our Data

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data.describe()
# Out:
#          Storage         RAM   Screen Size (inches)  Camera (MP)  \
# count  381.000000  381.000000            381.000000   381.000000
# mean   124.556430    5.879265              6.475932     4.185039
# std     66.124485    2.466857              0.310012     4.335255
# min     32.000000    2.000000              4.500000     0.000000
# 25%     64.000000    4.000000              6.440000     2.000000
# 50%    128.000000    6.000000              6.500000     2.000000
# 75%    128.000000    8.000000              6.580000     5.000000
# max    512.000000   16.000000              7.600000    48.000000
#
#        Battery Capacity (mAh)    Price ($)
# count              381.000000   381.000000
# mean              4683.958005   411.706037
# std                792.927831   305.185669
# min               1821.000000    99.000000
# 25%               4300.000000   199.000000
# 50%               5000.000000   299.000000
# 75%               5000.000000   499.000000
# max               7000.000000  1999.000000

# %%
data["Brand"].value_counts().plot.bar()
plt.title("The Distribution of Brands")
plt.show()

# %%
data.boxplot()
plt.xticks(rotation =15)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
numeric_cols= data.select_dtypes(include=['number']).columns

for i in numeric_cols :
    sns.boxplot(data =data , x= 'Brand' , y= i)
    plt.ylabel(i)
    plt.xticks(rotation=45)
    plt.title("box plot of "+i)
    plt.show()

# %%
numeric_cols= data.select_dtypes(include=['number']).columns.drop("Price ($)")

for i in numeric_cols :
    sns.scatterplot(data =data , x= i, y=  'Price ($)',hue='Brand')
    plt.ylabel(i)
    plt.xticks(rotation=45)
    plt.title("Price and "+i)
    plt.show()

# %%
numeric_cols= data.select_dtypes(include=['number'])
corr_mat=numeric_cols.corr()
sns.heatmap(corr_mat,annot=True, fmt='.2f')
# Out:
# <Axes: >

# %% [markdown]
# ### 4. Data Preprocessing

# %%
data.drop(columns=["Model"], inplace = True)

# %%
print(data.columns)
# Out:
# Index(['Brand', 'Storage ', 'RAM ', 'Screen Size (inches)', 'Camera (MP)',
#        'Battery Capacity (mAh)', 'Price ($)'],
#       dtype='object')

# %%
data=pd.get_dummies(data, columns=['Brand']) # mengubah teks menjadi numerik

# %%
data
# Out:
#      Storage   RAM   Screen Size (inches)  Camera (MP)  \
# 0         128     6                  6.10         12.0
# 1         256    12                  6.80         12.0
# 2         128     8                  6.70          2.0
# 3         128     6                  6.67          2.0
# 4         128     8                  6.40         12.2
# ..        ...   ...                   ...          ...
# 401       128     4                  6.15          2.0
# 402       128     8                  6.70         12.0
# 403       128     6                  6.57          2.0
# 404       128     6                  6.70         12.0
# 405       128     8                  6.40          2.0
#
#      Battery Capacity (mAh)  Price ($)  Brand_Apple  Brand_Asus  \
# 0                      3095        999         True       False
# 1                      5000       1199        False       False
# 2                      4500        899        False       False
# 3                      5020        279        False       False
# 4                      4614        799        False       False
# ..                      ...        ...          ...         ...
# 401                    3340        329        False       False
# 402                    4300       1049        False       False
# 403                    4160        349        False       False
# 404                    3687       1099         True       False
# 405                    4025        429        False       False
#
#      Brand_Blackberry  Brand_CAT  ...  Brand_LG  Brand_Motorola  Brand_Nokia  \
# 0               False      False  ...     False           False        False
# 1               False      False  ...     False           False        False
# 2               False      False  ...     False           False        False
# 3               False      False  ...     False           False        False
# 4               False      False  ...     False           False        False
# ..                ...        ...  ...       ...             ...          ...
# 401             False      False  ...     False           False        False
# 402             False      False  ...     False           False        False
# 403             False      False  ...     False           False        False
# 404             False      False  ...     False           False        False
# 405             False      False  ...     False           False        False
#
#      Brand_OnePlus  Brand_Oppo  Brand_Realme  Brand_Samsung  Brand_Sony  \
# 0            False       False         False          False       False
# 1            False       False         False           True       False
# 2             True       False         False          False       False
# 3            False       False         False          False       False
# 4            False       False         False          False       False
# ..             ...         ...           ...            ...         ...
# 401          False       False         False          False       False
# 402          False       False         False           True       False
# 403          False       False         False          False       False
# 404          False       False         False          False       False
# 405          False        True         False          False       False
#
#      Brand_Vivo  Brand_Xiaomi
# 0         False         False
# 1         False         False
# 2         False         False
# 3         False          True
# 4         False         False
# ..          ...           ...
# 401       False         False
# 402       False         False
# 403       False          True
# 404       False         False
# 405       False         False
#
# [381 rows x 22 columns]

# %%
data.columns.tolist()
# Out:
# ['Storage ',
#  'RAM ',
#  'Screen Size (inches)',
#  'Camera (MP)',
#  'Battery Capacity (mAh)',
#  'Price ($)',
#  'Brand_Apple',
#  'Brand_Asus',
#  'Brand_Blackberry',
#  'Brand_CAT',
#  'Brand_Google',
#  'Brand_Huawei',
#  'Brand_LG',
#  'Brand_Motorola',
#  'Brand_Nokia',
#  'Brand_OnePlus',
#  'Brand_Oppo',
#  'Brand_Realme',
#  'Brand_Samsung',
#  'Brand_Sony',
#  'Brand_Vivo',
#  'Brand_Xiaomi']

# %% [markdown]
# ### 5. Building Model

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Pisahkan fitur dan target
x = data.drop(columns=['Price ($)'])  # semua kolom kecuali harga
y = data['Price ($)']                 # target harga

# Normalisasi hanya fitur
scaler = MinMaxScaler()
x_scaled = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)

# Split data
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.3, random_state=42)

# Latih model
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
# Evaluasi performa model
mse = mean_squared_error(y_test, y_pred)                    # Mean Squared Error
mae = mean_absolute_error(y_test, y_pred)                   # Mean Absolute Error
r2 = r2_score(y_test, y_pred)                               # R² Score

# Tampilkan hasil dengan format rapi
print("=== Evaluasi Model Regresi Linear ===")
print(f"MSE  : {mse:.4f}")      # Semakin kecil semakin baik
print(f"MAE  : {mae:.4f}")      # Rata-rata selisih absolut
print(f"R²   : {r2:.4f}")       # Semakin mendekati 1 semakin baik
# Out:
# === Evaluasi Model Regresi Linear ===
# MSE  : 14126.4016
# MAE  : 85.5591
# R²   : 0.8380

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Buat figure
plt.figure(figsize=(7,7))

# Scatter plot: harga asli vs prediksi
sns.scatterplot(x=y_test, y=y_pred, color="dodgerblue", alpha=0.6, s=60)

# Garis diagonal (garis sempurna prediksi = real)
max_val = max(y_test.max(), y_pred.max())
min_val = min(y_test.min(), y_pred.min())
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--', linewidth=2, label="Perfect Prediction")

# Label dan judul
plt.title("Perbandingan Harga Asli vs Prediksi", fontsize=14)
plt.xlabel("Harga Asli (USD)")
plt.ylabel("Harga Prediksi (USD)")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %%
new_data = pd.DataFrame([{
    'Storage ': 256,
    'RAM ': 8,
    'Screen Size (inches)': 6.8,
    'Camera (MP)': 108,
    'Battery Capacity (mAh)': 5000,
    'Brand_Apple': 0,
    'Brand_Asus': 0,
    'Brand_Blackberry': 0,
    'Brand_CAT': 0,
    'Brand_Google': 0,
    'Brand_Huawei': 0,
    'Brand_LG': 0,
    'Brand_Motorola': 0,
    'Brand_Nokia': 0,
    'Brand_OnePlus': 0,
    'Brand_Oppo': 0,
    'Brand_Realme': 0,
    'Brand_Samsung': 0,
    'Brand_Sony': 0,
    'Brand_Vivo': 0,
    'Brand_Xiaomi': 0
}])

# Pastikan semua kolom sama urutan dan lengkap
for col in x.columns:
    if col not in new_data.columns:
        new_data[col] = 0

new_data = new_data[x.columns]

# Scaling pakai scaler lama
new_data_scaled = pd.DataFrame(scaler.transform(new_data), columns=x.columns)

# Prediksi
pred_price = model.predict(new_data_scaled)
print(f"Prediksi harga (USD): {pred_price[0]:.2f}")
# Out:
# Prediksi harga (USD): 2242.54

# %%
# Ambil semua kolom brand hp di x.columns 
brand_list = [col for col in x.columns if col.startswith('Brand_')]

def predict_phone_price(brand, storage, ram, camera, screen_size, battery) :
    new_data = pd.DataFrame([{
        'Storage ': storage,
        'RAM ': ram,
        'Screen Size (inches)': screen_size,
        'Camera (MP)': camera,
        'Battery Capacity (mAh)': battery,
    }])
    
    for b in brand_list:
        if b == f'Brand_{brand}':
            new_data[b] = 1
        else:
            new_data[b] = 0
            
    new_data = new_data[x.columns]
    
    new_data_scaled = pd.DataFrame(scaler.transform(new_data), columns=x.columns)
    
    predicted_price = model.predict(new_data_scaled)[0]
    
    print(f"📱 Prediksi harga untuk smartphone {brand} (Storage: {storage} GB, RAM: {ram} GB, Camera: {camera} MP dan Screen: {screen_size} inch): ${predicted_price:.2f}")
    return predicted_price

# %%
predict_phone_price(
    brand="Apple",
    storage=256,
    ram=8,
    camera=108,
    screen_size=6.8,
    battery=5000
)
# Out:
# 📱 Prediksi harga untuk smartphone Apple (Storage: 256 GB, RAM: 8 GB, Camera: 108 MP dan Screen: 6.8 inch): $2486.10
# np.float64(2486.102649555551)
